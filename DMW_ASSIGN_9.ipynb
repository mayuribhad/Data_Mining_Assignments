# %% [markdown]
# <a href="https://colab.research.google.com/github/mayuribhad/Data_Mining_Assignments/blob/main/DMW_ASSIGN_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Name - Mayuri Ashok Bhad
# #Batch - AB4
# #PRN No - UCS19F1007

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/diabetes.csv")

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#import train_test_split function
from sklearn.model_selection import train_test_split

#separate column in dependent and independent variables
x=data.drop('Outcome',axis=1)
y=data[['Outcome']]

# %%
#split dataset into training and test set
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)

# %%
#import Gaussian Neive Bayes model
from sklearn.naive_bayes import GaussianNB

#create a Guassian classifier
model=GaussianNB()

#Train the model using the training set
model.fit(x_train,y_train)

#predict the respomse for test dataset
y_pred=model.predict(x_test)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#evaluating model
from sklearn import metrics
print('accuracy:',metrics.accuracy_score(y_test,y_pred))
# Out:
# accuracy: 0.7835497835497836

# %%
test_pred=model.predict(x_test)
print(metrics.classification_report(y_test,test_pred))
print(metrics.confusion_matrix(y_test,test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       146
#            1       0.75      0.62      0.68        85
#
#     accuracy                           0.78       231
#    macro avg       0.77      0.75      0.76       231
# weighted avg       0.78      0.78      0.78       231
#
# [[128  18]
#  [ 32  53]]
